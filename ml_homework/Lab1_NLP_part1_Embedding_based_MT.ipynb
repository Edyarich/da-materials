# %% [markdown]
# # Lab 1
#
#
# ## Part 1: Bilingual dictionary induction and unsupervised embedding-based MT (30%)
# *Note: this homework is based on materials from yandexdataschool [NLP course](https://github.com/yandexdataschool/nlp_course/). Feel free to check this awesome course if you wish to dig deeper.*
#
# *Refined by [Nikolay Karpachev](https://www.linkedin.com/in/nikolay-karpachev-b0146a104/)*

# %% [markdown]
# **In this homework** **<font color='red'>YOU</font>** will make machine translation system without using parallel corpora, alignment, attention, 100500 depth super-cool recurrent neural network and all that kind superstuff.
#
# But even without parallel corpora this system can be good enough (hopefully), in particular for similar languages, e.g. Ukrainian and Russian.

# %% [markdown]
# ### Frament of the Swadesh list for some slavic languages
#
# The Swadesh list is a lexicostatistical stuff. It's named after American linguist Morris Swadesh and contains basic lexis. This list are used to define subgroupings of languages, its relatedness.
#
# So we can see some kind of word invariance for different Slavic languages.
#
#
# | Russian         | Belorussian              | Ukrainian               | Polish             | Czech                         | Bulgarian            |
# |-----------------|--------------------------|-------------------------|--------------------|-------------------------------|-----------------------|
# | женщина         | жанчына, кабета, баба    | жінка                   | kobieta            | žena                          | жена                  |
# | мужчина         | мужчына                  | чоловік, мужчина        | mężczyzna          | muž                           | мъж                   |
# | человек         | чалавек                  | людина, чоловік         | człowiek           | člověk                        | човек                 |
# | ребёнок, дитя   | дзіця, дзіцёнак, немаўля | дитина, дитя            | dziecko            | dítě                          | дете                  |
# | жена            | жонка                    | дружина, жінка          | żona               | žena, manželka, choť          | съпруга, жена         |
# | муж             | муж, гаспадар            | чоловiк, муж            | mąż                | muž, manžel, choť             | съпруг, мъж           |
# | мать, мама      | маці, матка              | мати, матір, неня, мама | matka              | matka, máma, 'стар.' mateř    | майка                 |
# | отец, тятя      | бацька, тата             | батько, тато, татусь    | ojciec             | otec                          | баща, татко           |
# | много           | шмат, багата             | багато                  | wiele              | mnoho, hodně                  | много                 |
# | несколько       | некалькі, колькі         | декілька, кілька        | kilka              | několik, pár, trocha          | няколко               |
# | другой, иной    | іншы                     | інший                   | inny               | druhý, jiný                   | друг                  |
# | зверь, животное | жывёла, звер, істота     | тварина, звір           | zwierzę            | zvíře                         | животно               |
# | рыба            | рыба                     | риба                    | ryba               | ryba                          | риба                  |
# | птица           | птушка                   | птах, птиця             | ptak               | pták                          | птица                 |
# | собака, пёс     | сабака                   | собака, пес             | pies               | pes                           | куче, пес             |
# | вошь            | вош                      | воша                    | wesz               | veš                           | въшка                 |
# | змея, гад       | змяя                     | змія, гад               | wąż                | had                           | змия                  |
# | червь, червяк   | чарвяк                   | хробак, черв'як         | robak              | červ                          | червей                |
# | дерево          | дрэва                    | дерево                  | drzewo             | strom, dřevo                  | дърво                 |
# | лес             | лес                      | ліс                     | las                | les                           | гора, лес             |
# | палка           | кій, палка               | палиця                  | patyk, pręt, pałka | hůl, klacek, prut, kůl, pálka | палка, пръчка, бастун |

# %% [markdown]
# But the context distribution of these languages demonstrates even more invariance. And we can use this fact for our for our purposes.

# %% [markdown]
# ## Data

# %% [markdown]
# In this notebook we're going to use pretrained word vectors - FastText (original paper - https://arxiv.org/abs/1607.04606).
#
# You can download them from the official [website](https://fasttext.cc/docs/en/crawl-vectors.html). We're going to need embeddings for Russian and Ukrainian languages.

# %%
# !wget -nc https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.ru.300.vec.gz
# !gzip -d cc.ru.300.vec.gz

# !wget -nc https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.uk.300.vec.gz
# !gzip -d cc.uk.300.vec.gz
# Out:
# --2022-04-11 07:03:09--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.ru.300.vec.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 104.22.74.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1306357571 (1.2G) [binary/octet-stream]
# Saving to: ‘cc.ru.300.vec.gz’
#
# cc.ru.300.vec.gz    100%[===================>]   1.22G  21.7MB/s    in 59s
#
# 2022-04-11 07:04:09 (21.1 MB/s) - ‘cc.ru.300.vec.gz’ saved [1306357571/1306357571]
#
# --2022-04-11 07:04:57--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.uk.300.vec.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 104.22.74.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1257595219 (1.2G) [binary/octet-stream]
# Saving to: ‘cc.uk.300.vec.gz’
#
# cc.uk.300.vec.gz    100%[===================>]   1.17G  23.2MB/s    in 55s
#
# 2022-04-11 07:05:52 (22.0 MB/s) - ‘cc.uk.300.vec.gz’ saved [1257595219/1257595219]

# %% [markdown]
# After downloading and extracting the vectors, we should be able to load them using the [gensim](https://radimrehurek.com/gensim/) library:

# %%
from gensim.models import KeyedVectors


uk_emb = KeyedVectors.load_word2vec_format("cc.uk.300.vec", limit=500000)
ru_emb = KeyedVectors.load_word2vec_format("cc.ru.300.vec", limit=500000)

# %% [markdown]
# Once you've loaded the vectors, you can use the `KeyedVectors` interface to get word embeddings and/or query most similar words by embedding:

# %%
august_embedding = ru_emb["август"]
august_embedding.shape, august_embedding[:5]
# Out:
# ((300,), array([ 0.0033, -0.0322, -0.0519, -0.0808, -0.0131], dtype=float32))

# %%
ru_emb.most_similar([august_embedding])
# Out:
# [('август', 1.0),
#  ('июль', 0.9383153915405273),
#  ('сентябрь', 0.9240028858184814),
#  ('июнь', 0.9222575426101685),
#  ('октябрь', 0.9095538854598999),
#  ('ноябрь', 0.8930036425590515),
#  ('апрель', 0.8729087114334106),
#  ('декабрь', 0.8652557730674744),
#  ('март', 0.8545796275138855),
#  ('февраль', 0.8401416540145874)]

# %% [markdown]
# The latter function also allows you to vary the amount of closest words via the `topn` argument:

# %%
ru_emb.most_similar([august_embedding], topn=3)
# Out:
# [('август', 1.0),
#  ('июль', 0.9383153915405273),
#  ('сентябрь', 0.9240028858184814)]

# %% [markdown]
# Another feature of `KeyedVectors` is that it allows to compute embeddings for multiple words simultaneously:

# %%
ru_emb[["август", "сентябрь"]].shape
# Out:
# (2, 300)

# %% [markdown]
# Everything above is true for the embeddings for Ukrainian language.

# %%
uk_emb.most_similar([uk_emb["серпень"]])
# Out:
# [('серпень', 0.9999999403953552),
#  ('липень', 0.9096440076828003),
#  ('вересень', 0.901697039604187),
#  ('червень', 0.8992519378662109),
#  ('жовтень', 0.8810408711433411),
#  ('листопад', 0.8787633776664734),
#  ('квітень', 0.8592804670333862),
#  ('грудень', 0.8586863279342651),
#  ('травень', 0.8408110737800598),
#  ('лютий', 0.8256431818008423)]

# %% [markdown]
# However, russian and ukrainian embeddings were trained independently of each other. This means, that there is no obvious connection between values in embeddings for similar words in Russian and Ukrainian:

# %%
ru_emb.most_similar([uk_emb["серпень"]])
# Out:
# [('Недопустимость', 0.24435284733772278),
#  ('конструктивность', 0.23293080925941467),
#  ('офор', 0.23256804049015045),
#  ('deteydlya', 0.23031717538833618),
#  ('пресечении', 0.22632381319999695),
#  ('одностороннего', 0.22608885169029236),
#  ('подход', 0.2230587601661682),
#  ('конструктивное', 0.21656131744384766),
#  ('подхода', 0.2142382562160492),
#  ('Семёныч', 0.2130262702703476)]

# %% [markdown]
# ## Translation

# %% [markdown]
# We'll build a simple translator, which will try to predict the russian embedding from the ukrainian one. For this we'll need a dataset of word pairs.

# %%
import pandas as pd


train_data_url = "https://raw.githubusercontent.com/girafe-ai/ml-mipt/22s_advanced/homeworks_advanced/Lab1_NLP/uk_ru.train.tsv"
train_data = pd.read_csv(train_data_url, sep="\t", header=None)
train_data.columns = ["uk", "ru"]
print(f"Train dataset size: {len(train_data)}")

test_data_url = "https://raw.githubusercontent.com/girafe-ai/ml-mipt/22s_advanced/homeworks_advanced/Lab1_NLP/uk_ru.test.tsv"
test_data = pd.read_csv(test_data_url, sep="\t", header=None)
test_data.columns = ["uk", "ru"]
print(f"Test dataset size: {len(test_data)}")

train_data.head()
# Out:
# Train dataset size: 1927
# Test dataset size: 400
#          uk          ru
# 0  iмовірно    вероятно
# 1     iснує  существует
# 2     iспит     экзамен
# 3     абияк  как-нибудь
# 4       або         или

# %% [markdown]
# Our method won't work with unknown words, so let's filter them out:

# %%
rows = []
for _, row in train_data.iterrows():
    if row["uk"] not in uk_emb or row["ru"] not in ru_emb:
        continue

    rows.append(row)

train_data = pd.DataFrame(rows)
print(f"Train dataset size: {len(train_data)}")

rows = []
for _, row in test_data.iterrows():
    if row["uk"] not in uk_emb or row["ru"] not in ru_emb:
        continue

    rows.append(row)

test_data = pd.DataFrame(rows)
print(f"Test dataset size: {len(test_data)}")
# Out:
# Train dataset size: 1833
# Test dataset size: 385

# %% [markdown]
# We will train our model to predict embedding for the russian word from embedding of its ukrainian counterpart. For this reason we split our train and test data into ukrainian and russian words and compute corresponding embeddings to obtain `X` (ukrainian embeddings) and `y` (russian embeddings).

# %%
X_train, Y_train = uk_emb[train_data["uk"].values], ru_emb[train_data["ru"].values]
X_test, Y_test = uk_emb[test_data["uk"].values], ru_emb[test_data["ru"].values]

# %% [markdown]
# ## Embedding space mapping (0.3 pts)

# %% [markdown]
# Let $x_i \in \mathrm{R}^d$ be the distributed representation of word $i$ in the source language, and $y_i \in \mathrm{R}^d$ is the vector representation of its translation. Our purpose is to learn such linear transform $W$ that minimizes euclidian distance between $Wx_i$ and $y_i$ for some subset of word embeddings. Thus we can formulate so-called Procrustes problem:
#
# $$W^*= \arg\min_W \sum_{i=1}^n\|Wx_i - y_i\|_2$$
#
# or
#
# $$W^*= \arg\min_W \|XW^T - Y\|_F$$
#
# where $\|\cdot\|_F$ denotes Frobenius norm.
#
# > **Note:** in second formula, $W$ and $x$ seem to have switched places. This happens because the $X$ matrix is composed of objects $x_i$ in *rows* not *columns*, i.e. it is kind of composed of $x_i^T$. This means that $X \in \mathbb{R}^{N \times D}$, where $N$ is the number of items and $D$ is the embedding dimensionality. The same is true for the $Y$.

# %% [markdown]
# $W^*= \arg\min_W \sum_{i=1}^n\|Wx_i - y_i\|_2$ looks like simple multiple linear regression without bias. The `sklearn` allows you to turn off the bias in `LinearRegression` via the `fit_intercept` argument (in fact they simply call bias the intercept). So let's code.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


mapping = LinearRegression(fit_intercept=False)
mapping.fit(X_train, Y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %% [markdown]
# Let's take a look at neigbours of the vector of word _"серпень"_ (_"август"_ in Russian) after linear transform.

# %%
august = mapping.predict(uk_emb["серпень"].reshape(1, -1))
ru_emb.most_similar(august)
# Out:
# [('апрель', 0.8544619083404541),
#  ('июнь', 0.8420493602752686),
#  ('март', 0.8402518033981323),
#  ('сентябрь', 0.8365459442138672),
#  ('февраль', 0.8335456848144531),
#  ('октябрь', 0.8318145275115967),
#  ('ноябрь', 0.828838586807251),
#  ('июль', 0.824008584022522),
#  ('август', 0.8121696710586548),
#  ('декабрь', 0.8047348260879517)]

# %% [markdown]
# We can see that neighbourhood of this embedding cosists of different months, but right variant is on the ninth place.

# %% [markdown]
# As quality measure we will use precision top-1, top-5 and top-10 (for each transformed ukrainian embedding we count how many right target pairs are found in top N nearest neighbours in russian embedding space).

# %%
def precision(pairs, mapped_vectors, topn=1):
    """
    :args:
        pairs = list of right word pairs [(uk_word_0, ru_word_0), ...]
        mapped_vectors = list of embeddings after mapping from source embedding space to destination embedding space
        topn = the number of nearest neighbours in destination embedding space to choose from
    :returns:
        precision_val, float number, total number of words for those we can find right translation at top K.
    """
    assert len(pairs) == len(mapped_vectors)
    total = len(pairs)
    correct = 0

    for i in range(total):
        keyword, correct_target_word = pairs[i]
        predicted_vector = mapped_vectors[i][None, :]
        similar_keywords = [word for word, score in \
                            ru_emb.most_similar(predicted_vector, topn=topn)]

        if correct_target_word in similar_keywords:
            correct += 1

    return correct / total

# %%
assert precision([("серпень", "август")], august, topn=5) == 0.0
assert precision([("серпень", "август")], august, topn=9) == 1.0
assert precision([("серпень", "август")], august, topn=10) == 1.0

# %% [markdown]
# Note that our `precision` function accepts lists of pairs of words, whereas we have dataframes. However, it is not a problem: we can get a list (actually, numpy array) of pairs via the `values` property.

# %%
assert precision(test_data.values, X_test) == 0.0
assert precision(test_data.values, Y_test) == 1.0

# %% [markdown]
# Let's see how well our model is doing.

# %%
top1 = precision(test_data.values, mapping.predict(X_test), 1)
print(f"Top-1 precision {100 * top1:.1f}%")

top5 = precision(test_data.values, mapping.predict(X_test), 5)
print(f"Top-5 precision {100 * top5:.1f}%")
# Out:
# Top-1 precision 64.2%
# Top-5 precision 81.6%

# %% [markdown]
# ## Making it better (orthogonal Procrustean problem) (0.3 pts)

# %% [markdown]
# It can be shown that a self-consistent linear mapping between semantic spaces should be orthogonal.
# We can restrict transform $W$ to be orthogonal. Then we will solve next problem:
#
# $$(W^T)^*= \arg\min_{W^T} \|XW^T - Y\|_F \text{, where: } W^TW = I$$
#
# $$I \text{- identity matrix}$$
#
# Instead of making yet another regression problem we can find optimal orthogonal transformation using singular value decomposition. It turns out that optimal transformation $W^*$ can be expressed via SVD components:
# $$X^TY=U\Sigma V^T\text{, singular value decompostion}$$
# $$(W^T)^*=UV^T$$

# %%
import numpy as np


u, _, vh = np.linalg.svd(np.dot(X_train.T, Y_train))
mapping = np.dot(u, vh)

# %% [markdown]
# Now our `mapping` is just a numpy array, meaning that it has no `predict` method. However, from the formulae above we know, that prediction is done using the matrix multiplication:

# %%
august = uk_emb["серпень"] @ mapping
ru_emb.most_similar([august])
# Out:
# [('апрель', 0.8242579698562622),
#  ('сентябрь', 0.8054481744766235),
#  ('март', 0.8030693531036377),
#  ('июнь', 0.8020994663238525),
#  ('октябрь', 0.8013110756874084),
#  ('ноябрь', 0.7944729328155518),
#  ('февраль', 0.7919864654541016),
#  ('июль', 0.7909592986106873),
#  ('август', 0.788949728012085),
#  ('декабрь', 0.7691435813903809)]

# %% [markdown]
# Now let's compute our precision values and see, whether our trick did improve the results.

# %%
top1 = precision(test_data.values, X_test @ mapping, 1)
print(f"Top-1 precision {100 * top1:.1f}%")

top5 = precision(test_data.values, X_test @ mapping, 5)
print(f"Top-5 precision {100 * top5:.1f}%")
# Out:
# Top-1 precision 65.7%
# Top-5 precision 83.1%

# %% [markdown]
# ## Unsupervised embedding-based MT (0.4 pts)

# %% [markdown]
# Now, let's build our word embeddings-based translator!

# %% [markdown]
# Firstly, download OPUS Tatoeba corpus.

# %%
# !wget https://object.pouta.csc.fi/OPUS-Tatoeba/v20190709/mono/uk.txt.gz
# !gzip -d ./uk.txt.gz
# Out:
# --2022-04-11 07:10:14--  https://object.pouta.csc.fi/OPUS-Tatoeba/v20190709/mono/uk.txt.gz
# Resolving object.pouta.csc.fi (object.pouta.csc.fi)... 86.50.254.18, 86.50.254.19
# Connecting to object.pouta.csc.fi (object.pouta.csc.fi)|86.50.254.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1819128 (1.7M) [application/gzip]
# Saving to: ‘uk.txt.gz’
#
# uk.txt.gz           100%[===================>]   1.73M  1.01MB/s    in 1.7s
#
# 2022-04-11 07:10:18 (1.01 MB/s) - ‘uk.txt.gz’ saved [1819128/1819128]

# %%
with open('./uk.txt', 'r') as f:
    uk_corpus = f.readlines()

# To save your time and CPU, feel free to use first 1000 sentences of the corpus
uk_corpus = uk_corpus[:1000]
uk_corpus[:5]
# Out:
# ['Я вже закінчу коледж, коли ви вернетеся з Америки.\n',
#  'Він наказав мені негайно вийти з кімнати.\n',
#  'Як би ти не намагався, ти не вивчиш англійську за два-три місяці.\n',
#  'Поки я не подзвонив, він не прийшов.\n',
#  'У всесвіті багато галактик.\n']

# %% [markdown]
# Now let's translate these sentences word-by-word. Before that, however, don't forget to tokenize your sentences. For that you may (or may not) find the `nltk.tokenize.WordPunctTokenizer` to be very useful.

# %%
from nltk.tokenize import WordPunctTokenizer


tokenizer = WordPunctTokenizer()

# %%
def translate(sentence, tokenizer=tokenizer):
    """
    :args:
        sentence - sentence in Ukrainian (str)
    :returns:
        translation - sentence in Russian (str)

    * find ukrainian embedding for each word in sentence
    * transform ukrainian embedding vector
    * find nearest russian word and replace
    """
    translated = []

    for word in tokenizer.tokenize(sentence):
        if not word.isalpha():
            translated.append(word)
            continue
        
        try:
            word_emb = uk_emb[word]
        except KeyError:
            translated.append("UNK")
            continue

        transformed_emb = word_emb[None, :] @ mapping
        translation_word, _ = ru_emb.most_similar(transformed_emb, topn=1)[0]
        translated.append(translation_word)

    return " ".join(translated)

# %%
assert translate(".") == "."
assert translate("1 , 3") == "1 , 3"
assert translate("кіт зловив мишу") == "кот поймал мышку"

# %% [markdown]
# Now you can play with your model and try to get as accurate translations as possible. **Note**: one big issue is out-of-vocabulary words. Try to think of various ways of handling it (you can start with translating each of them to a special **UNK** token and then move to more sophisticated approaches). Good luck!

# %%
for sent in uk_corpus[::20]:
    print(translate(sent) + " <---> " + sent)
# Out:
# Я уже закончу колледж , когда мы UNK со Америки . <---> Я вже закінчу коледж, коли ви вернетеся з Америки.
#
# Возможно , мной UNK , конечно оно не означает , что мной не общаюсь со людьми . <---> Можливо, я антисоціальний, але це не означає, що я не спілкуюся з людьми.
#
# Беда не приходит одна . <---> Біда не приходить одна.
#
# Я заказал два гамбургера . <---> Я замовив два гамбургера.
#
# Гора покрыта снегом . <---> Гора вкрита снігом.
#
# Во меня То мечта . <---> У мене є мрія.
#
# по север находится Шотландия ; по юге — Англия ; по юге — Уэльс ; и ещ дальше по юге — северная Ирландия . <---> На півночі знаходиться Шотландія; на півдні — Англія; на заході — Уельс; і ще далі на заході — Північна Ірландія.
#
# Берн — столица Швейцарии . <---> Берн — столиця Швейцарії.
#
# Ты можешь взять ту книгу даром . <---> Ти можеш взяти цю книгу даром.
#
# забронировать , будьте ласковые , комнату возле международного аэропорта во Лос-Анджелесе . <---> Забронюйте, будьте ласкаві, кімнату біля міжнародного аеропорту в Торонто.
#
# Я знаю , что ты богатый . <---> Я знаю, що ти багатий.
#
# Во этой реке опасно плавать . <---> В цій річці небезпечно плавати.
#
# Я хожу к школы пешком . <---> Я ходжу до школи пішки.
#
# Не забудь билет . <---> Не забудь квиток.
#
# мы будете чай ли кофе ? <---> Ви будете чай чи каву?
#
# Когда мы родились ? <---> Коли Ви народилися?
#
# мы почти семь ’ мной . <---> Ми майже сім’я.
#
# Я против любой - которых войны . <---> Я проти будь-яких війн.
#
# Говорят , что американцы считают количество денег , какую зарабатывает женщина , мерилом его умение . <---> Кажуть, що американці вважають кількість грошей, яку заробляє людина, мірилом його уміння.
#
# Если будет красивая погода , мы UNK туда завтра . <---> Якщо буде гарна погода, ми доберемося туди завтра.
#
# Один , два , три , четыре , аш ' пять , восемь , семь , восемь , девять ' пять , десять . <---> Один, два, три, чотири, п'ять, шість, сім, вісім, дев'ять, десять.
#
# Его иметь волнуется за него . <---> Його мати хвилюється за нього.
#
# необычайная дружба переросла во глубокое любовь . <---> Їхня дружба переросла у глибоке кохання.
#
# Он вор . <---> Він злодій.
#
# чай со лимоном , будьте ласковые . <---> Чай з лимоном, будьте ласкаві.
#
# Я бы со удовольствием сочинил сотни текста во UNK ’ и , конечно во меня То дела . <---> Я би з задоволенням написав сотні речень в Tatoeb’і, але в мене є справи.
#
# ведь же ты никогда мне о оно не рассказывала ! <---> Але ж ти ніколи мені про це не розповідала!
#
# Запах роз наполнил комнату . <---> Запах троянд наповнив кімнату.
#
# Это мои штаны . <---> Це мої штани.
#
# Я не понимаю , почему Франция победила по Евровидении . <---> Я не розумію, чому Німеччина перемогла на Євробаченні.
#
# Со UNK Алексея UNK поприветствовал президент Белоруссии Александр Лукашенко . <---> З юбілеєм Олексія Дударева привітав Президент Білорусі Олександр Лукашенко.
#
# удивительно видеть рок - звёзд со галстук ! <---> Незвичайно бачити рок-зірок з краваткою!
#
# ЧТо мне одеть — штаны ли юбку ? <---> Що мені вдягнути — штани чи спідницю?
#
# Ой был злой кролик . <---> То був злий кролик.
#
# Конечно мной пойду . <---> Звичайно я піду.
#
# ЧТо бы ты сделала , если бы во тебя было , UNK , десять тысяч долларов ? <---> Що б ти зробила, якщо б у тебе було, скажім, десять тисяч доларів?
#
# она очень гордится своею коллекцией марок . <---> Вона дуже пишається своєю колекцією марок.
#
# Какая ты добра ! <---> Яка ти добра!
#
# Это всё , что мной знаю . <---> Це все, що я знаю.
#
# Тебе решать . <---> Тобі вирішувати.
#
# Это всё , что мной хочу сделать . <---> Це все, що я хочу зробити.
#
# тная песня напоминает мне о дом . <---> Ця пісня нагадує мені про дім.
#
# Меня зовут Фрэнк . <---> Мене звуть Джек.
#
# Я здесь уже две часа . <---> Я тут уже дві години.
#
# Сегодня мной видел скворца . <---> Сьогодні я бачив шпака.
#
# UNK медведи , как правило , очень опасные . <---> Ранені ведмеді, як правило, дуже небезпечні.
#
# остальные готовы . <---> Усі готові.
#
# « Спасибо », — « по здоровье ' мной ». <---> «Дякую», — «На здоров'я».
#
# Амазонка — вторая по длине река во мире после Нила . <---> Амазонка— друга по довжині ріка в світі після Ніла.
#
# закрой за собой дверь . <---> Закрий за собою двері.

# %% [markdown]
# Great!
# See second notebook for the Neural Machine Translation assignment.

# %% [markdown]
# <b> Для слов, не лежащих в словаре, зададим его эмбеддинг как среднее значение эмбеддингов соседних слов</b>

# %%
def translate(sentence, tokenizer=tokenizer, window_size=2):
    """
    :args:
        sentence - sentence in Ukrainian (str)
    :returns:
        translation - sentence in Russian (str)

    * find ukrainian embedding for each word in sentence
    * transform ukrainian embedding vector
    * find nearest russian word and replace
    """
    translated = []
    tokens = tokenizer.tokenize(sentence)

    for i, word in enumerate(tokens):
        if not word.isalpha():
            translated.append(word)
            continue

        if word in uk_emb:
            word_emb = uk_emb[word].reshape(1, -1)
        else:
            j, k = i-1, i+1
            known_prev_words, known_future_words = 0, 0
            word_emb = np.zeros((1, uk_emb.vector_size))

            while j >= 0 and known_prev_words < window_size:
                if tokens[j].isalpha() and tokens[j] in uk_emb:
                    word_emb += uk_emb[tokens[j]]
                    known_prev_words += 1

                j -= 1

            while k < len(tokens) and known_future_words < window_size:
                if tokens[k].isalpha() and tokens[k] in uk_emb:
                    word_emb += uk_emb[tokens[k]]
                    known_future_words += 1

                k += 1
            
            if known_prev_words + known_future_words == 0:
                translated.append("UNK")
                continue

        transformed_emb = word_emb @ mapping
        translation_word, _ = ru_emb.most_similar(transformed_emb, topn=1)[0]
        translated.append(translation_word)

    return " ".join(translated)

# %% [markdown]
# <b> Проверка корректности </b>

# %%
assert translate(".") == "."
assert translate("1 , 3") == "1 , 3"
assert translate("кіт зловив мишу") == "кот поймал мышку"

# %% [markdown]
# <b> Полученный перевод</b>
#
# Как можно видеть, предложенный метод плохо переводит слова не из словаря:
#
# вернетеся --- с \
# антисоціальний --- это \
# доберемося --- мы \
# юбілеєм --- со \
# скажім --- десять \
# Ранені --- как \

# %%
for sent in uk_corpus[::20]:
    print(translate(sent) + " <---> " + sent)
# Out:
# Я уже закончу колледж , когда мы с со Америки . <---> Я вже закінчу коледж, коли ви вернетеся з Америки.
#
# Возможно , мной это , конечно оно не означает , что мной не общаюсь со людьми . <---> Можливо, я антисоціальний, але це не означає, що я не спілкуюся з людьми.
#
# Беда не приходит одна . <---> Біда не приходить одна.
#
# Я заказал два гамбургера . <---> Я замовив два гамбургера.
#
# Гора покрыта снегом . <---> Гора вкрита снігом.
#
# Во меня То мечта . <---> У мене є мрія.
#
# по север находится Шотландия ; по юге — Англия ; по юге — Уэльс ; и ещ дальше по юге — северная Ирландия . <---> На півночі знаходиться Шотландія; на півдні — Англія; на заході — Уельс; і ще далі на заході — Північна Ірландія.
#
# Берн — столица Швейцарии . <---> Берн — столиця Швейцарії.
#
# Ты можешь взять ту книгу даром . <---> Ти можеш взяти цю книгу даром.
#
# забронировать , будьте ласковые , комнату возле международного аэропорта во Лос-Анджелесе . <---> Забронюйте, будьте ласкаві, кімнату біля міжнародного аеропорту в Торонто.
#
# Я знаю , что ты богатый . <---> Я знаю, що ти багатий.
#
# Во этой реке опасно плавать . <---> В цій річці небезпечно плавати.
#
# Я хожу к школы пешком . <---> Я ходжу до школи пішки.
#
# Не забудь билет . <---> Не забудь квиток.
#
# мы будете чай ли кофе ? <---> Ви будете чай чи каву?
#
# Когда мы родились ? <---> Коли Ви народилися?
#
# мы почти семь ’ мной . <---> Ми майже сім’я.
#
# Я против любой - которых войны . <---> Я проти будь-яких війн.
#
# Говорят , что американцы считают количество денег , какую зарабатывает женщина , мерилом его умение . <---> Кажуть, що американці вважають кількість грошей, яку заробляє людина, мірилом його уміння.
#
# Если будет красивая погода , мы мы туда завтра . <---> Якщо буде гарна погода, ми доберемося туди завтра.
#
# Один , два , три , четыре , аш ' пять , восемь , семь , восемь , девять ' пять , десять . <---> Один, два, три, чотири, п'ять, шість, сім, вісім, дев'ять, десять.
#
# Его иметь волнуется за него . <---> Його мати хвилюється за нього.
#
# необычайная дружба переросла во глубокое любовь . <---> Їхня дружба переросла у глибоке кохання.
#
# Он вор . <---> Він злодій.
#
# чай со лимоном , будьте ласковые . <---> Чай з лимоном, будьте ласкаві.
#
# Я бы со удовольствием сочинил сотни текста во во ’ и , конечно во меня То дела . <---> Я би з задоволенням написав сотні речень в Tatoeb’і, але в мене є справи.
#
# ведь же ты никогда мне о оно не рассказывала ! <---> Але ж ти ніколи мені про це не розповідала!
#
# Запах роз наполнил комнату . <---> Запах троянд наповнив кімнату.
#
# Это мои штаны . <---> Це мої штани.
#
# Я не понимаю , почему Франция победила по Евровидении . <---> Я не розумію, чому Німеччина перемогла на Євробаченні.
#
# Со Со Алексея Со поприветствовал президент Белоруссии Александр Лукашенко . <---> З юбілеєм Олексія Дударева привітав Президент Білорусі Олександр Лукашенко.
#
# удивительно видеть рок - звёзд со галстук ! <---> Незвичайно бачити рок-зірок з краваткою!
#
# ЧТо мне одеть — штаны ли юбку ? <---> Що мені вдягнути — штани чи спідницю?
#
# Ой был злой кролик . <---> То був злий кролик.
#
# Конечно мной пойду . <---> Звичайно я піду.
#
# ЧТо бы ты сделала , если бы во тебя было , десять , десять тысяч долларов ? <---> Що б ти зробила, якщо б у тебе було, скажім, десять тисяч доларів?
#
# она очень гордится своею коллекцией марок . <---> Вона дуже пишається своєю колекцією марок.
#
# Какая ты добра ! <---> Яка ти добра!
#
# Это всё , что мной знаю . <---> Це все, що я знаю.
#
# Тебе решать . <---> Тобі вирішувати.
#
# Это всё , что мной хочу сделать . <---> Це все, що я хочу зробити.
#
# тная песня напоминает мне о дом . <---> Ця пісня нагадує мені про дім.
#
# Меня зовут Фрэнк . <---> Мене звуть Джек.
#
# Я здесь уже две часа . <---> Я тут уже дві години.
#
# Сегодня мной видел скворца . <---> Сьогодні я бачив шпака.
#
# как медведи , как правило , очень опасные . <---> Ранені ведмеді, як правило, дуже небезпечні.
#
# остальные готовы . <---> Усі готові.
#
# « Спасибо », — « по здоровье ' мной ». <---> «Дякую», — «На здоров'я».
#
# Амазонка — вторая по длине река во мире после Нила . <---> Амазонка— друга по довжині ріка в світі після Ніла.
#
# закрой за собой дверь . <---> Закрий за собою двері.
