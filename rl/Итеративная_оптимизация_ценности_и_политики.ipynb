# %% [markdown]
# # Марковский процесс принятия решений
#
# #### дедлайн (жёсткий) задания: 3 апреля, 23:59 UTC+3
#
# #### при сдаче задания нужно данный файл послать в систему сдачи
#
# В данной работе рассматриваются методы, разработанные для решения Марковских процессов принятия решений, **M**arkov **D**ecision **P**rocesses, **MDP**. В самом широком смысле, MDP определяется тем, как он изменяет состояния и как вычисляются награды.
#
# Переход состояний определяется распределением $P(s' |s,a)$ &mdash; насколько вероятно перейти в состояние $s'$, если производится действие $a$ в состоянии $s$. Существует несколько способов определить функцию вознаграждений, однако ради удобства будет использована следующая сигнатура: $r(s,a,s')$.

# %% [markdown]
# # Работа выполнена: Владимиров Эдуард, М05-304а

# %% [markdown]
# Для начала, давайте определим простой MDP, изображённый на рисунке ниже:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/ad/Markov_Decision_Process.svg" width="400px" alt="Diagram by Waldoalvarez via Wikimedia Commons, CC BY-SA 4.0"/>

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's2': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')

# %% [markdown]
# Теперь можно использовать MDP как и другие среды от Open AI Gym:

# %%
print('initial state =', mdp.reset())
next_state, reward, done, info = mdp.step('a1')
print('next_state = %s, reward = %s, done = %s' % (next_state, reward, done))
# Out:
# initial state = s0
# next_state = s2, reward = 0.0, done = False

# %% [markdown]
# но также есть и другие методы, необходимые для имплементации алгоритма итерацонной оптимизации ценности (Value Iteration)

# %%
print("mdp.get_all_states =", mdp.get_all_states())
print("mdp.get_possible_actions('s1') = ", mdp.get_possible_actions('s1'))
print("mdp.get_next_states('s1', 'a0') = ", mdp.get_next_states('s1', 'a0'))
print("mdp.get_reward('s1', 'a0', 's0') = ", mdp.get_reward('s1', 'a0', 's0'))
print("mdp.get_transition_prob('s1', 'a0', 's0') = ",
      mdp.get_transition_prob('s1', 'a0', 's0'))
# Out:
# mdp.get_all_states = ('s0', 's1', 's2')
# mdp.get_possible_actions('s1') =  ('a0', 'a1')
# mdp.get_next_states('s1', 'a0') =  {'s0': 0.7, 's1': 0.1, 's2': 0.2}
# mdp.get_reward('s1', 'a0', 's0') =  5
# mdp.get_transition_prob('s1', 'a0', 's0') =  0.7

# %% [markdown]
# ### Опционально: визуализация MDP
#
# Вы можете визуализировать MDP с помощью функции отрисовки, написанной [neer201](https://github.com/neer201).
#
# Для этого требуется установить graphviz системно и для Python. На Unix-подобных системах (Ubuntu) для этого достатчно выполнить следующие команды:
#
# 1. `sudo apt-get install graphviz`
# 2. `pip install graphviz`
# 3. перезагрузить этот ноутбук
#
# __Замечание:__ Установка graphviz на некоторые ОС (особенно Windows) может быть нетривиальной. Поэтому можно пропусить данный шаг и использовать стандартную визуализацию.

# %%
from mdp import has_graphviz
from IPython.display import display
print("Graphviz доступен:", has_graphviz)
# Out:
# Graphviz доступен: True

# %%
if has_graphviz:
    from mdp import plot_graph, plot_graph_with_state_values, \
        plot_graph_optimal_strategy_and_state_values

    display(plot_graph(mdp))

# %% [markdown]
# # Итерационная оптимизация ценности, Value Iteration (вплоть до 4 баллов)
#
# Теперь построим первый способ решения MDP. Простейший на данный момент алгоритм называется итерационной оптимизацией ценности или __V__alue __I__teration
#
# Ниже представлен псевдокод VI:
#
# ---
#
# `1.` Инициализация $V^{(0)}(s)=0$, for all $s$
#
# `2.` Для $i=0, 1, 2, \dots$
#
# `3.` $ \quad V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$, для всех $s$
#
# ---

# %% [markdown]
# Для начала выпишем функцию вычисления $Q$-функции ценности $Q^{\pi}$, определив следующим образом
#
# $$Q_i(s, a) = \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$$

# %%
# %%writefile mdp_get_action_value.py
def get_action_value(mdp, state_values, state, action, gamma):
    """ Вычисляет Q(s,a) согласно формуле выше """
    q_func = 0
    
    for next_state, proba in mdp.get_next_states(state, action).items():
        reward = mdp.get_reward(state, action, next_state)
        v_func = state_values[next_state]
        q_func += proba * (reward + gamma * v_func)
    
    return q_func
# Out:
# Writing mdp_get_action_value.py

# %%
from mdp_get_action_value import *

# %%
import numpy as np
test_Vs = {s: i for i, s in enumerate(sorted(mdp.get_all_states()))}
assert np.isclose(get_action_value(mdp, test_Vs, 's2', 'a1', 0.9), 0.69)
assert np.isclose(get_action_value(mdp, test_Vs, 's1', 'a0', 0.9), 3.95)

# %% [markdown]
# Используя $Q(s,a)$ можно определить "следующее" $V(s)$ для итерационной оптимизации ценности.
#  $$V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = \max_a Q_i(s,a)$$

# %%
def get_new_state_value(mdp, state_values, state, gamma):
    """ Вычисляет следующее V(s) согласно формуле выше. Просьба не изменять state_values в процессе. """
    if mdp.is_terminal(state):
        return 0
    
    max_action_val = -float('inf')
    
    for action in mdp.get_possible_actions(state):
        action_val = get_action_value(mdp, state_values, state, action, gamma)
        max_action_val = max(action_val, max_action_val)
    
    return max_action_val

# %%
test_Vs_copy = dict(test_Vs)
assert np.isclose(get_new_state_value(mdp, test_Vs, 's0', 0.9), 1.8)
assert np.isclose(get_new_state_value(mdp, test_Vs, 's2', 0.9), 1.08)
assert test_Vs == test_Vs_copy, "просьба не изменять state_values в get_new_state_value"

# %% [markdown]
# Наконец-то можно скомбинировать написанное в работающий алгоритм.

# %%
# %%time

# гиперпараметры
gamma = 0.9            # фактор дисконтирования MDP
num_iter = 100         # максимальное количество итераций, не включая инициализацию
# останов VI, если новые значения V(s) настолько близки к старым (или ближе)
min_difference = 0.001

# инициализация V(s)
state_values = {s: 0 for s in mdp.get_all_states()}

if has_graphviz:
    display(plot_graph_with_state_values(mdp, state_values))

for i in range(num_iter):

    # Вычисление новых V(s) используя определённые выше функции.
    # Должен быть словарь {state : float V_new(state)}
    new_state_values = {s: get_new_state_value(mdp, state_values, s, gamma) for s in mdp.get_all_states()}

    assert isinstance(new_state_values, dict)

    # Вычисление темпоральных различий V(s)
    diff = max(abs(new_state_values[s] - state_values[s])
               for s in mdp.get_all_states())
    print("Итерация %4i   |   разность max_s|V_new(s) - V_old(s)|: %6.5f   |   " % (i, diff), end="")
    print('   '.join("V(%s) = %.3f" % (s, v) for s, v in state_values.items()))
    state_values = new_state_values

    if diff < min_difference:
        print("Останов")
        break
# Out:
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 3.50000   |   V(s0) = 0.000   V(s1) = 0.000   V(s2) = 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.64500   |   V(s0) = 0.000   V(s1) = 3.500   V(s2) = 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.58050   |   V(s0) = 0.000   V(s1) = 3.815   V(s2) = 0.645
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.43582   |   V(s0) = 0.581   V(s1) = 3.959   V(s2) = 0.962
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.30634   |   V(s0) = 0.866   V(s1) = 4.395   V(s2) = 1.272
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.27571   |   V(s0) = 1.145   V(s1) = 4.670   V(s2) = 1.579
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.24347   |   V(s0) = 1.421   V(s1) = 4.926   V(s2) = 1.838
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.21419   |   V(s0) = 1.655   V(s1) = 5.169   V(s2) = 2.075
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.19277   |   V(s0) = 1.868   V(s1) = 5.381   V(s2) = 2.290
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.17327   |   V(s0) = 2.061   V(s1) = 5.573   V(s2) = 2.481
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.15569   |   V(s0) = 2.233   V(s1) = 5.746   V(s2) = 2.654
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.14012   |   V(s0) = 2.389   V(s1) = 5.902   V(s2) = 2.810
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.12610   |   V(s0) = 2.529   V(s1) = 6.042   V(s2) = 2.950
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.11348   |   V(s0) = 2.655   V(s1) = 6.168   V(s2) = 3.076
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.10213   |   V(s0) = 2.769   V(s1) = 6.282   V(s2) = 3.190
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.09192   |   V(s0) = 2.871   V(s1) = 6.384   V(s2) = 3.292
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.08272   |   V(s0) = 2.963   V(s1) = 6.476   V(s2) = 3.384
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.07445   |   V(s0) = 3.045   V(s1) = 6.558   V(s2) = 3.467
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.06701   |   V(s0) = 3.120   V(s1) = 6.633   V(s2) = 3.541
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.06031   |   V(s0) = 3.187   V(s1) = 6.700   V(s2) = 3.608
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.05428   |   V(s0) = 3.247   V(s1) = 6.760   V(s2) = 3.668
# Итерация   21   |   разность max_s|V_new(s) - V_old(s)|: 0.04885   |   V(s0) = 3.301   V(s1) = 6.814   V(s2) = 3.723
# Итерация   22   |   разность max_s|V_new(s) - V_old(s)|: 0.04396   |   V(s0) = 3.350   V(s1) = 6.863   V(s2) = 3.771
# Итерация   23   |   разность max_s|V_new(s) - V_old(s)|: 0.03957   |   V(s0) = 3.394   V(s1) = 6.907   V(s2) = 3.815
# Итерация   24   |   разность max_s|V_new(s) - V_old(s)|: 0.03561   |   V(s0) = 3.434   V(s1) = 6.947   V(s2) = 3.855
# Итерация   25   |   разность max_s|V_new(s) - V_old(s)|: 0.03205   |   V(s0) = 3.469   V(s1) = 6.982   V(s2) = 3.891
# Итерация   26   |   разность max_s|V_new(s) - V_old(s)|: 0.02884   |   V(s0) = 3.502   V(s1) = 7.014   V(s2) = 3.923
# Итерация   27   |   разность max_s|V_new(s) - V_old(s)|: 0.02596   |   V(s0) = 3.530   V(s1) = 7.043   V(s2) = 3.951
# Итерация   28   |   разность max_s|V_new(s) - V_old(s)|: 0.02336   |   V(s0) = 3.556   V(s1) = 7.069   V(s2) = 3.977
# Итерация   29   |   разность max_s|V_new(s) - V_old(s)|: 0.02103   |   V(s0) = 3.580   V(s1) = 7.093   V(s2) = 4.001
# Итерация   30   |   разность max_s|V_new(s) - V_old(s)|: 0.01892   |   V(s0) = 3.601   V(s1) = 7.114   V(s2) = 4.022
# Итерация   31   |   разность max_s|V_new(s) - V_old(s)|: 0.01703   |   V(s0) = 3.620   V(s1) = 7.133   V(s2) = 4.041
# Итерация   32   |   разность max_s|V_new(s) - V_old(s)|: 0.01533   |   V(s0) = 3.637   V(s1) = 7.150   V(s2) = 4.058
# Итерация   33   |   разность max_s|V_new(s) - V_old(s)|: 0.01380   |   V(s0) = 3.652   V(s1) = 7.165   V(s2) = 4.073
# Итерация   34   |   разность max_s|V_new(s) - V_old(s)|: 0.01242   |   V(s0) = 3.666   V(s1) = 7.179   V(s2) = 4.087
# Итерация   35   |   разность max_s|V_new(s) - V_old(s)|: 0.01117   |   V(s0) = 3.678   V(s1) = 7.191   V(s2) = 4.099
# Итерация   36   |   разность max_s|V_new(s) - V_old(s)|: 0.01006   |   V(s0) = 3.689   V(s1) = 7.202   V(s2) = 4.110
# Итерация   37   |   разность max_s|V_new(s) - V_old(s)|: 0.00905   |   V(s0) = 3.699   V(s1) = 7.212   V(s2) = 4.121
# Итерация   38   |   разность max_s|V_new(s) - V_old(s)|: 0.00815   |   V(s0) = 3.708   V(s1) = 7.221   V(s2) = 4.130
# Итерация   39   |   разность max_s|V_new(s) - V_old(s)|: 0.00733   |   V(s0) = 3.717   V(s1) = 7.230   V(s2) = 4.138
# Итерация   40   |   разность max_s|V_new(s) - V_old(s)|: 0.00660   |   V(s0) = 3.724   V(s1) = 7.237   V(s2) = 4.145
# Итерация   41   |   разность max_s|V_new(s) - V_old(s)|: 0.00594   |   V(s0) = 3.731   V(s1) = 7.244   V(s2) = 4.152
# Итерация   42   |   разность max_s|V_new(s) - V_old(s)|: 0.00534   |   V(s0) = 3.736   V(s1) = 7.249   V(s2) = 4.158
# Итерация   43   |   разность max_s|V_new(s) - V_old(s)|: 0.00481   |   V(s0) = 3.742   V(s1) = 7.255   V(s2) = 4.163
# Итерация   44   |   разность max_s|V_new(s) - V_old(s)|: 0.00433   |   V(s0) = 3.747   V(s1) = 7.260   V(s2) = 4.168
# Итерация   45   |   разность max_s|V_new(s) - V_old(s)|: 0.00390   |   V(s0) = 3.751   V(s1) = 7.264   V(s2) = 4.172
# Итерация   46   |   разность max_s|V_new(s) - V_old(s)|: 0.00351   |   V(s0) = 3.755   V(s1) = 7.268   V(s2) = 4.176
# Итерация   47   |   разность max_s|V_new(s) - V_old(s)|: 0.00316   |   V(s0) = 3.758   V(s1) = 7.271   V(s2) = 4.179
# Итерация   48   |   разность max_s|V_new(s) - V_old(s)|: 0.00284   |   V(s0) = 3.762   V(s1) = 7.275   V(s2) = 4.183
# Итерация   49   |   разность max_s|V_new(s) - V_old(s)|: 0.00256   |   V(s0) = 3.764   V(s1) = 7.277   V(s2) = 4.185
# Итерация   50   |   разность max_s|V_new(s) - V_old(s)|: 0.00230   |   V(s0) = 3.767   V(s1) = 7.280   V(s2) = 4.188
# Итерация   51   |   разность max_s|V_new(s) - V_old(s)|: 0.00207   |   V(s0) = 3.769   V(s1) = 7.282   V(s2) = 4.190
# Итерация   52   |   разность max_s|V_new(s) - V_old(s)|: 0.00186   |   V(s0) = 3.771   V(s1) = 7.284   V(s2) = 4.192
# Итерация   53   |   разность max_s|V_new(s) - V_old(s)|: 0.00168   |   V(s0) = 3.773   V(s1) = 7.286   V(s2) = 4.194
# Итерация   54   |   разность max_s|V_new(s) - V_old(s)|: 0.00151   |   V(s0) = 3.775   V(s1) = 7.288   V(s2) = 4.196
# Итерация   55   |   разность max_s|V_new(s) - V_old(s)|: 0.00136   |   V(s0) = 3.776   V(s1) = 7.289   V(s2) = 4.197
# Итерация   56   |   разность max_s|V_new(s) - V_old(s)|: 0.00122   |   V(s0) = 3.778   V(s1) = 7.291   V(s2) = 4.199
# Итерация   57   |   разность max_s|V_new(s) - V_old(s)|: 0.00110   |   V(s0) = 3.779   V(s1) = 7.292   V(s2) = 4.200
# Итерация   58   |   разность max_s|V_new(s) - V_old(s)|: 0.00099   |   V(s0) = 3.780   V(s1) = 7.293   V(s2) = 4.201
# Останов
# CPU times: user 18.4 ms, sys: 23.2 ms, total: 41.6 ms
# Wall time: 153 ms

# %%
if has_graphviz:
    display(plot_graph_with_state_values(mdp, state_values))

# %%
print("Финальные ценности состояний:", state_values)

assert abs(state_values['s0'] - 3.781) < 0.01
assert abs(state_values['s1'] - 7.294) < 0.01
assert abs(state_values['s2'] - 4.202) < 0.01
# Out:
# Финальные ценности состояний: {'s0': 3.7810348735476405, 's1': 7.294006423867229, 's2': 4.202140275227048}

# %% [markdown]
# Теперь используем полученные $V^{*}(s)$ для определения оптимальных действий в каждом состоянии
#
#  $$\pi^*(s) = argmax_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = argmax_a Q_i(s,a)$$
#
# Единственное отличие по сравнению с вычислением `V(s)` состоит в извлечении не `max`, а `argmax`: поиск действия с максимальной ценностью `Q(s,a)`.

# %%
def get_optimal_action(mdp, state_values, state, gamma=0.9):
    """ Выбор оптимального действия, используя формулу выше. """
    if mdp.is_terminal(state):
        return None
    
    max_action_val = -float('inf')
    best_action = None
    
    for action in mdp.get_possible_actions(state):
        action_val = get_action_value(mdp, state_values, state, action, gamma)
        
        if action_val > max_action_val:
            max_action_val = action_val
            best_action = action
    
    return best_action

# %%
assert get_optimal_action(mdp, state_values, 's0', gamma) == 'a1'
assert get_optimal_action(mdp, state_values, 's1', gamma) == 'a0'
assert get_optimal_action(mdp, state_values, 's2', gamma) == 'a1'

# %%
if has_graphviz:
    try:
        display(plot_graph_optimal_strategy_and_state_values(mdp, state_values))
    except ImportError:
        raise ImportError("Запустите ячейку, начинающуюся с \"%%writefile mdp_get_action_value.py\"")

# %%
# %%time

# Оценка средней награды агента

s = mdp.reset()
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
    rewards.append(r)

print("средняя награда: ", np.mean(rewards))

assert(0.40 < np.mean(rewards) < 0.55)
# Out:
# средняя награда:  0.4644
# CPU times: user 263 ms, sys: 140 ms, total: 403 ms
# Wall time: 310 ms

# %% [markdown]
# ### Frozen lake

# %%
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)

mdp.render()
# Out:
# *FFF
# FHFH
# FFFH
# HFFG

# %%
def value_iteration(mdp, state_values=None, gamma=0.9, num_iter=1000, min_difference=1e-5, verbose=True):
    """ Выполняет num_iter шагов итерационной оптимизации ценности, начиная с state_values.
         То же, что и ранее, но в формате функции """
    state_values = state_values or {s: 0 for s in mdp.get_all_states()}
    for i in range(num_iter):

        # Вычислить новые ценности состояний, используя определённые выше функции.
        # В результате должен получиться словарь формата {state : new_V(state)}
        new_state_values = {s: get_new_state_value(mdp, state_values, s, gamma) for s in mdp.get_all_states()}

        assert isinstance(new_state_values, dict)

        # Вычислить темпоральную разность по значениям ценности
        diff = max(abs(new_state_values[s] - state_values[s])
                   for s in mdp.get_all_states())
        
        if verbose:
            print("Итерация %4i   |   разность max_s|V_new(s) - V_old(s)|: %6.5f   |   V(start): %.3f " %
                  (i, diff, new_state_values[mdp._initial_state]))

        state_values = new_state_values
        if diff < min_difference:
            break

    return state_values

# %%
# %%time

state_values = value_iteration(mdp)
# Out:
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 1.00000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.90000   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.81000   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.72900   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.65610   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.59049   |   V(start): 0.590
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.590
# CPU times: user 5.91 ms, sys: 2.94 ms, total: 8.85 ms
# Wall time: 6.7 ms

# %%
# %%time

s = mdp.reset()
mdp.render()
for t in range(100):
    a = get_optimal_action(mdp, state_values, s, gamma)
    print(a, end='\n\n')
    s, r, done, _ = mdp.step(a)
    mdp.render()
    if done:
        break
# Out:
# *FFF
# FHFH
# FFFH
# HFFG
#
# down
#
# SFFF
# *HFH
# FFFH
# HFFG
#
# down
#
# SFFF
# FHFH
# *FFH
# HFFG
#
# right
#
# SFFF
# FHFH
# F*FH
# HFFG
#
# down
#
# SFFF
# FHFH
# FFFH
# H*FG
#
# right
#
# SFFF
# FHFH
# FFFH
# HF*G
#
# right
#
# SFFF
# FHFH
# FFFH
# HFF*
#
# CPU times: user 2.74 ms, sys: 0 ns, total: 2.74 ms
# Wall time: 2.16 ms

# %% [markdown]
# ### Время визуализаций!
#
# Обычно полезно и интересно видеть, что в действительности Ваш алгоритм выучивает под капотом. Для этого можно изобразить V-функцию и оптимальные действия на каждом шаге алгоритма VI.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


def draw_policy(mdp, state_values):
    plt.figure(figsize=(3, 3))
    h, w = mdp.desc.shape
    states = sorted(mdp.get_all_states())
    V = np.array([state_values[s] for s in states])
    Pi = {s: get_optimal_action(mdp, state_values, s, gamma) for s in states}
    plt.imshow(V.reshape(w, h), cmap='gray', interpolation='none', clim=(0, 1))
    ax = plt.gca()
    ax.set_xticks(np.arange(h)-.5)
    ax.set_yticks(np.arange(w)-.5)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    Y, X = np.mgrid[0:4, 0:4]
    a2uv = {'left': (-1, 0), 'down': (0, -1), 'right': (1, 0), 'up': (-1, 0)}
    for y in range(h):
        for x in range(w):
            plt.text(x, y, str(mdp.desc[y, x].item()),
                     color='g', size=12,  verticalalignment='center',
                     horizontalalignment='center', fontweight='bold')
            a = Pi[y, x]
            if a is None:
                continue
            u, v = a2uv[a]
            plt.arrow(x, y, u*.3, -v*.3, color='m',
                      head_width=0.1, head_length=0.1)
    plt.grid(color='b', lw=2, ls='-')
    plt.show()

# %%
# %%time

state_values = {s: 0 for s in mdp.get_all_states()}

for i in range(10):
    print("после итерации %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
# просьба игнорировать отладочный вывод "Итерация 0" на каждом шаге
# Out:
# после итерации 0
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 1.00000   |   V(start): 0.000
# после итерации 1
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.90000   |   V(start): 0.000
# после итерации 2
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.81000   |   V(start): 0.000
# после итерации 3
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.72900   |   V(start): 0.000
# после итерации 4
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.65610   |   V(start): 0.000
# после итерации 5
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.59049   |   V(start): 0.590
# после итерации 6
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.590
# после итерации 7
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.590
# после итерации 8
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.590
# после итерации 9
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.590
# CPU times: user 1.32 s, sys: 1.94 s, total: 3.26 s
# Wall time: 681 ms

# %%
# %%time

from IPython.display import clear_output
from time import sleep
mdp = FrozenLakeEnv(map_name='8x8', slip_chance=0.1)
state_values = {s: 0 for s in mdp.get_all_states()}

for i in range(30):
    clear_output(True)
    print("после итерации %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
    sleep(0.5)
# просьба игнорировать отладочный вывод "Итерация 0" на каждом шаге
# Out:
# после итерации 29
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.198
# CPU times: user 10.6 s, sys: 4.6 s, total: 15.2 s
# Wall time: 24 s

# %% [markdown]
# Массовые испытания

# %%
# %%time

mdp = FrozenLakeEnv(slip_chance=0)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("средняя награда: ", np.mean(total_rewards))
assert(1.0 <= np.mean(total_rewards) <= 1.0)
print("Отлинчая работа!")
# Out:
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 1.00000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.90000   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.81000   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.72900   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.65610   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.59049   |   V(start): 0.590
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.590
# средняя награда:  1.0
# Отлинчая работа!
# CPU times: user 212 ms, sys: 1.2 ms, total: 213 ms
# Wall time: 210 ms

# %%
# %%time

# Оценка средней награды агента
mdp = FrozenLakeEnv(slip_chance=0.1)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("средняя награда: ", np.mean(total_rewards))
assert(0.8 <= np.mean(total_rewards) <= 0.95)
print("Отличная работа!")
# Out:
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.90000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.72900   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.62330   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.50487   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.40894   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.34868   |   V(start): 0.349
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.06529   |   V(start): 0.410
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.05832   |   V(start): 0.468
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.01139   |   V(start): 0.480
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.00764   |   V(start): 0.487
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.00164   |   V(start): 0.489
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.00094   |   V(start): 0.490
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.00022   |   V(start): 0.490
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.00011   |   V(start): 0.490
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.490
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.490
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.490
# средняя награда:  0.896
# Отличная работа!
# CPU times: user 385 ms, sys: 102 ms, total: 487 ms
# Wall time: 398 ms

# %%
# %%time

# Оценка средней награды агента
mdp = FrozenLakeEnv(slip_chance=0.25)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("средняя награда: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.7)
print("Отличная работа!")
# Out:
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.75000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.50625   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.39867   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.26910   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.18164   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.14013   |   V(start): 0.140
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.07028   |   V(start): 0.199
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.06030   |   V(start): 0.260
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.02594   |   V(start): 0.285
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.01918   |   V(start): 0.305
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.00858   |   V(start): 0.313
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.00560   |   V(start): 0.319
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.00260   |   V(start): 0.321
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.00159   |   V(start): 0.323
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.00076   |   V(start): 0.324
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.00045   |   V(start): 0.324
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.00022   |   V(start): 0.324
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.00012   |   V(start): 0.325
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.00006   |   V(start): 0.325
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.325
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.00002   |   V(start): 0.325
# Итерация   21   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.325
# средняя награда:  0.658
# Отличная работа!
# CPU times: user 438 ms, sys: 21.3 ms, total: 460 ms
# Wall time: 448 ms

# %%
# %%time

# Оценка средней награды агента
mdp = FrozenLakeEnv(slip_chance=0.2, map_name='8x8')
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("средняя награда: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.8)
print("Отличная работа!")
# Out:
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.80000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.57600   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.41472   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.29860   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.24186   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.19349   |   V(start): 0.000
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.15325   |   V(start): 0.000
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.12288   |   V(start): 0.000
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.09930   |   V(start): 0.000
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.08037   |   V(start): 0.000
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.06426   |   V(start): 0.000
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.05129   |   V(start): 0.000
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.04330   |   V(start): 0.000
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.03802   |   V(start): 0.033
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.03332   |   V(start): 0.058
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.02910   |   V(start): 0.087
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.01855   |   V(start): 0.106
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.01403   |   V(start): 0.120
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.00810   |   V(start): 0.128
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.00555   |   V(start): 0.133
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.00321   |   V(start): 0.137
# Итерация   21   |   разность max_s|V_new(s) - V_old(s)|: 0.00247   |   V(start): 0.138
# Итерация   22   |   разность max_s|V_new(s) - V_old(s)|: 0.00147   |   V(start): 0.139
# Итерация   23   |   разность max_s|V_new(s) - V_old(s)|: 0.00104   |   V(start): 0.140
# Итерация   24   |   разность max_s|V_new(s) - V_old(s)|: 0.00058   |   V(start): 0.140
# Итерация   25   |   разность max_s|V_new(s) - V_old(s)|: 0.00036   |   V(start): 0.141
# Итерация   26   |   разность max_s|V_new(s) - V_old(s)|: 0.00024   |   V(start): 0.141
# Итерация   27   |   разность max_s|V_new(s) - V_old(s)|: 0.00018   |   V(start): 0.141
# Итерация   28   |   разность max_s|V_new(s) - V_old(s)|: 0.00012   |   V(start): 0.141
# Итерация   29   |   разность max_s|V_new(s) - V_old(s)|: 0.00007   |   V(start): 0.141
# Итерация   30   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.141
# Итерация   31   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.141
# Итерация   32   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.141
# Итерация   33   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.141
# средняя награда:  0.735
# Отличная работа!
# CPU times: user 385 ms, sys: 37.6 ms, total: 423 ms
# Wall time: 392 ms

# %% [markdown]
# # Итерационная оптимизация политики, Policy Iteration (вплоть до 4 баллов)
#
# Требуется имплементировать явную итерационную оптимизацию политики, Policy Iteration (PI) согласно следующему псевдокоду:
#
# ---
# Инициализация $\pi_0$   `// случайная или константная`
#
# Для $n=0, 1, 2, \dots$
# - Вычислить функцию $V^{\pi_{n}}$
# - С помощью $V^{\pi_{n}}$, вычислить функцию $Q^{\pi_{n}}$
# - Вычислить новую политику $\pi_{n+1}(s) = \operatorname*{argmax}_a Q^{\pi_{n}}(s,a)$
# ---
#
# В отличие от VI, Policy Iteration требует явное вычисление политики &mdash; выбранное действие для каждого состояния &mdash; и оценку $V^{\pi_{n}}$ на основе данной политики. Обновление политики происходит после (итеративного) вычисления V-функции.
#
#
# Ниже представлены несколько функций-помощников, которые могут оказаться полезными при имплементации методов.

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's1': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')

# %% [markdown]
# Настало время написать функцию под названием `compute_vpi`, которая вычисляет функцию $V^{\pi}$ для произвольной политики $\pi$.
#
# В отличие от VI, в этот раз требуется точное решение, не просто одна итерация.
#
# Напоминаем, что $V^{\pi}$ удовлетворяет следующему линейному соотношению:
# $$V^{\pi}(s) = \sum_{s'} P(s,\pi(s),s')[ R(s,\pi(s),s') + \gamma V^{\pi}(s')]$$
#
# Вам потребуется решить систему линейных алгебраических уравнений в коде. (Найдите точное решение, например, С помощью `np.linalg.solve` или метода простых итераций.)

# %%
def compute_vpi(mdp, policy, gamma):
    """
    Вычисляет V^pi(s) ДЛЯ ВСЕХ СОСТОЯНИЙ при текущей политике.
    :параметр policy: словарь выбранных на данный момент действий {s : a}
    :возвращает: словарь {state : V^pi(state) для всех state}
    """
    # V = U + gamma * P @ R
    # V = (I - gamma * P)^-1 @ R
    num_states = len(mdp.get_all_states())
    P = np.zeros((num_states, num_states))
    R = np.zeros(num_states)
    state_to_index = {state: idx for idx, state in enumerate(mdp.get_all_states())}
    
    for state in mdp.get_all_states():
        if mdp.is_terminal(state):
            continue
        action = policy[state]
        for next_state, prob in mdp.get_next_states(state, action).items():
            P[state_to_index[state], state_to_index[next_state]] += prob
            R[state_to_index[state]] += prob * mdp.get_reward(state, action, next_state)
    
    I = np.eye(num_states)
    V = np.linalg.solve(I - gamma * P, R)
    
    return {state: V[state_to_index[state]] for state in mdp.get_all_states()}

# %%
# %%time

test_policy = {s: np.random.choice(
    mdp.get_possible_actions(s)) for s in mdp.get_all_states()}
new_vpi = compute_vpi(mdp, test_policy, gamma)

print(new_vpi)

assert type(
    new_vpi) is dict, "compute_vpi должен возвращать словарь {state : V^pi(state) для всех state}"
# Out:
# {'s0': 2.8399699474079663, 's1': 6.498873027798649, 's2': 3.4710743801652932}
# CPU times: user 2.34 ms, sys: 3.26 ms, total: 5.61 ms
# Wall time: 52.2 ms

# %% [markdown]
# Как только получены новые ценности состояний, время обновить текущую политику.

# %%
def compute_new_policy(mdp, vpi, gamma):
    """
    Вычисляет жадно новую политику как argmax по функции ценности
    :параметр vpi: словарь {state : V^pi(state) для всех state}
    :возвращает: словарь {state : оптимальное действие для всех state}
    """
    new_policy = dict()
    
    for state in mdp.get_all_states():
        action = get_optimal_action(mdp, vpi, state, gamma)
        new_policy[state] = action
    
    return new_policy

# %%
# %%time

new_policy = compute_new_policy(mdp, new_vpi, gamma)

print(new_policy)

assert type(
    new_policy) is dict, "compute_new_policy должен возвращать словарь {состояние : оптимальное действие}"
# Out:
# {'s0': 'a1', 's1': 'a0', 's2': 'a0'}
# CPU times: user 234 µs, sys: 120 µs, total: 354 µs
# Wall time: 366 µs

# %% [markdown]
# __Основной цикл__

# %%
def policy_iteration(mdp, policy=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """ 
    Запуск итерационной оптимизации политики в цикле на num_iter итераций, или пока max_s|V_new(s) - V_old(s)|
    не станет меньше min_difference. Если начальная политика не дана, то инициализация случайная.
    """
    if policy is None:
        policy = {}
        for state in mdp.get_all_states():
            possible_actions = mdp.get_possible_actions(state)
            if possible_actions:
                policy[state] = np.random.choice(possible_actions)
    
    for i in range(num_iter):
        vpi = compute_vpi(mdp, policy, gamma)
        new_policy = compute_new_policy(mdp, vpi, gamma)
        new_vpi = compute_vpi(mdp, new_policy, gamma)
        
        deltas = [abs(vpi[state] - new_vpi[state]) for state in mdp.get_all_states()]
        max_delta = max(deltas)
        
        policy = new_policy
        
        if max_delta < min_difference:
            break
    
    state_values = compute_vpi(mdp, policy, gamma)
    
    return state_values, policy

# %% [markdown]
# __Ваши результаты экспериментирования с PI__

# %%
def run_experiment(environment, algorithm, **params):
    """
    Возврат результатов: время выполнения, число итераций, средняя награда
    """
    map_size, slip_chance = environment
    mdp = FrozenLakeEnv(slip_chance=slip_chance, map_name=map_size)
    
    state_values = algorithm(mdp)[0] if algorithm is policy_iteration else algorithm(mdp)

    total_rewards = []
    iterations = []
    
    for game_i in range(1000):
        s = mdp.reset()
        rewards = []
        for t in range(200):
                s, r, done, _ = mdp.step(
                    get_optimal_action(mdp, state_values, s, gamma))
            rewards.append(r)
            if done:
                iterations.append(t+1)
                break
        
        total_rewards.append(np.sum(rewards))

    return np.mean(iterations), np.mean(total_rewards)

# %%
environments = [('4x4', 0.1), ('4x4', 0.2), ('4x4', 0.3), ('8x8', 0.1), ('8x8', 0.2), ('8x8', 0.3)]
algorithms = [policy_iteration, value_iteration]

for env in environments:
    for algo in algorithms:
        results = run_experiment(env, algo)
        print(f"Environment: {env[0]}, Slip chance: {env[1]}, Algorithm: {algo.__name__}, Iterations: {results[0]}, Rewards: {results[1]}")
# Out:
# Environment: 4x4, Slip chance: 0.1, Algorithm: policy_iteration, Iterations: 6.297, Rewards: 0.893
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.90000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.72900   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.62330   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.50487   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.40894   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.34868   |   V(start): 0.349
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.06529   |   V(start): 0.410
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.05832   |   V(start): 0.468
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.01139   |   V(start): 0.480
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.00764   |   V(start): 0.487
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.00164   |   V(start): 0.489
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.00094   |   V(start): 0.490
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.00022   |   V(start): 0.490
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.00011   |   V(start): 0.490
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.490
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.490
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.490
# Environment: 4x4, Slip chance: 0.1, Algorithm: value_iteration, Iterations: 6.153, Rewards: 0.879
# Environment: 4x4, Slip chance: 0.2, Algorithm: policy_iteration, Iterations: 6.291, Rewards: 0.731
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.80000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.57600   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.46656   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.33592   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.24186   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.19349   |   V(start): 0.193
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.07575   |   V(start): 0.260
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.06614   |   V(start): 0.326
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.02373   |   V(start): 0.350
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.01704   |   V(start): 0.367
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.00647   |   V(start): 0.373
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.00406   |   V(start): 0.377
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.00162   |   V(start): 0.379
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.00094   |   V(start): 0.380
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.00039   |   V(start): 0.380
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.00022   |   V(start): 0.380
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.00009   |   V(start): 0.380
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.00005   |   V(start): 0.380
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.00002   |   V(start): 0.380
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.380
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.380
# Environment: 4x4, Slip chance: 0.2, Algorithm: value_iteration, Iterations: 6.153, Rewards: 0.702
# Environment: 4x4, Slip chance: 0.3, Algorithm: policy_iteration, Iterations: 6.318, Rewards: 0.567
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.70000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.44100   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.33736   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.21254   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.13390   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.09924   |   V(start): 0.099
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.06134   |   V(start): 0.149
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.05149   |   V(start): 0.200
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.02551   |   V(start): 0.226
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.01936   |   V(start): 0.245
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.00981   |   V(start): 0.255
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.00662   |   V(start): 0.262
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.00344   |   V(start): 0.265
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.00219   |   V(start): 0.267
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.00117   |   V(start): 0.268
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.00072   |   V(start): 0.269
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.00039   |   V(start): 0.270
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.00023   |   V(start): 0.270
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.00013   |   V(start): 0.270
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.00008   |   V(start): 0.270
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.270
# Итерация   21   |   разность max_s|V_new(s) - V_old(s)|: 0.00002   |   V(start): 0.270
# Итерация   22   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.270
# Итерация   23   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.270
# Environment: 4x4, Slip chance: 0.3, Algorithm: value_iteration, Iterations: 6.291, Rewards: 0.568
# Environment: 8x8, Slip chance: 0.1, Algorithm: policy_iteration, Iterations: 15.057, Rewards: 0.885
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.90000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.72900   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.59049   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.47830   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.40894   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.34868   |   V(start): 0.000
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.29655   |   V(start): 0.000
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.25292   |   V(start): 0.000
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.21619   |   V(start): 0.000
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.18482   |   V(start): 0.000
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.15757   |   V(start): 0.000
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.13430   |   V(start): 0.000
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.11445   |   V(start): 0.000
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.09751   |   V(start): 0.098
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.04772   |   V(start): 0.139
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.03479   |   V(start): 0.173
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.01283   |   V(start): 0.186
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.00734   |   V(start): 0.194
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.00255   |   V(start): 0.196
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.00125   |   V(start): 0.197
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.00042   |   V(start): 0.198
# Итерация   21   |   разность max_s|V_new(s) - V_old(s)|: 0.00019   |   V(start): 0.198
# Итерация   22   |   разность max_s|V_new(s) - V_old(s)|: 0.00006   |   V(start): 0.198
# Итерация   23   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.198
# Итерация   24   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.198
# Итерация   25   |   разность max_s|V_new(s) - V_old(s)|: 0.00000   |   V(start): 0.198
# Environment: 8x8, Slip chance: 0.1, Algorithm: value_iteration, Iterations: 15.087, Rewards: 0.876
# Environment: 8x8, Slip chance: 0.2, Algorithm: policy_iteration, Iterations: 16.434, Rewards: 0.719
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.80000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.57600   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.41472   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.29860   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.24186   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.19349   |   V(start): 0.000
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.15325   |   V(start): 0.000
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.12288   |   V(start): 0.000
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.09930   |   V(start): 0.000
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.08037   |   V(start): 0.000
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.06426   |   V(start): 0.000
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.05129   |   V(start): 0.000
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.04330   |   V(start): 0.000
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.03802   |   V(start): 0.033
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.03332   |   V(start): 0.058
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.02910   |   V(start): 0.087
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.01855   |   V(start): 0.106
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.01403   |   V(start): 0.120
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.00810   |   V(start): 0.128
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.00555   |   V(start): 0.133
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.00321   |   V(start): 0.137
# Итерация   21   |   разность max_s|V_new(s) - V_old(s)|: 0.00247   |   V(start): 0.138
# Итерация   22   |   разность max_s|V_new(s) - V_old(s)|: 0.00147   |   V(start): 0.139
# Итерация   23   |   разность max_s|V_new(s) - V_old(s)|: 0.00104   |   V(start): 0.140
# Итерация   24   |   разность max_s|V_new(s) - V_old(s)|: 0.00058   |   V(start): 0.140
# Итерация   25   |   разность max_s|V_new(s) - V_old(s)|: 0.00036   |   V(start): 0.141
# Итерация   26   |   разность max_s|V_new(s) - V_old(s)|: 0.00024   |   V(start): 0.141
# Итерация   27   |   разность max_s|V_new(s) - V_old(s)|: 0.00018   |   V(start): 0.141
# Итерация   28   |   разность max_s|V_new(s) - V_old(s)|: 0.00012   |   V(start): 0.141
# Итерация   29   |   разность max_s|V_new(s) - V_old(s)|: 0.00007   |   V(start): 0.141
# Итерация   30   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.141
# Итерация   31   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.141
# Итерация   32   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.141
# Итерация   33   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.141
# Environment: 8x8, Slip chance: 0.2, Algorithm: value_iteration, Iterations: 16.335, Rewards: 0.719
# Environment: 8x8, Slip chance: 0.3, Algorithm: policy_iteration, Iterations: 18.31, Rewards: 0.602
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.70000   |   V(start): 0.000
# Итерация    1   |   разность max_s|V_new(s) - V_old(s)|: 0.44100   |   V(start): 0.000
# Итерация    2   |   разность max_s|V_new(s) - V_old(s)|: 0.27783   |   V(start): 0.000
# Итерация    3   |   разность max_s|V_new(s) - V_old(s)|: 0.17503   |   V(start): 0.000
# Итерация    4   |   разность max_s|V_new(s) - V_old(s)|: 0.13390   |   V(start): 0.000
# Итерация    5   |   разность max_s|V_new(s) - V_old(s)|: 0.09924   |   V(start): 0.000
# Итерация    6   |   разность max_s|V_new(s) - V_old(s)|: 0.07190   |   V(start): 0.000
# Итерация    7   |   разность max_s|V_new(s) - V_old(s)|: 0.05782   |   V(start): 0.000
# Итерация    8   |   разность max_s|V_new(s) - V_old(s)|: 0.05018   |   V(start): 0.000
# Итерация    9   |   разность max_s|V_new(s) - V_old(s)|: 0.04372   |   V(start): 0.000
# Итерация   10   |   разность max_s|V_new(s) - V_old(s)|: 0.03715   |   V(start): 0.000
# Итерация   11   |   разность max_s|V_new(s) - V_old(s)|: 0.03166   |   V(start): 0.000
# Итерация   12   |   разность max_s|V_new(s) - V_old(s)|: 0.02624   |   V(start): 0.000
# Итерация   13   |   разность max_s|V_new(s) - V_old(s)|: 0.02151   |   V(start): 0.009
# Итерация   14   |   разность max_s|V_new(s) - V_old(s)|: 0.01746   |   V(start): 0.019
# Итерация   15   |   разность max_s|V_new(s) - V_old(s)|: 0.01489   |   V(start): 0.033
# Итерация   16   |   разность max_s|V_new(s) - V_old(s)|: 0.01299   |   V(start): 0.045
# Итерация   17   |   разность max_s|V_new(s) - V_old(s)|: 0.01125   |   V(start): 0.057
# Итерация   18   |   разность max_s|V_new(s) - V_old(s)|: 0.00855   |   V(start): 0.065
# Итерация   19   |   разность max_s|V_new(s) - V_old(s)|: 0.00689   |   V(start): 0.072
# Итерация   20   |   разность max_s|V_new(s) - V_old(s)|: 0.00502   |   V(start): 0.077
# Итерация   21   |   разность max_s|V_new(s) - V_old(s)|: 0.00416   |   V(start): 0.081
# Итерация   22   |   разность max_s|V_new(s) - V_old(s)|: 0.00308   |   V(start): 0.083
# Итерация   23   |   разность max_s|V_new(s) - V_old(s)|: 0.00239   |   V(start): 0.085
# Итерация   24   |   разность max_s|V_new(s) - V_old(s)|: 0.00196   |   V(start): 0.087
# Итерация   25   |   разность max_s|V_new(s) - V_old(s)|: 0.00160   |   V(start): 0.087
# Итерация   26   |   разность max_s|V_new(s) - V_old(s)|: 0.00132   |   V(start): 0.088
# Итерация   27   |   разность max_s|V_new(s) - V_old(s)|: 0.00100   |   V(start): 0.088
# Итерация   28   |   разность max_s|V_new(s) - V_old(s)|: 0.00076   |   V(start): 0.089
# Итерация   29   |   разность max_s|V_new(s) - V_old(s)|: 0.00058   |   V(start): 0.089
# Итерация   30   |   разность max_s|V_new(s) - V_old(s)|: 0.00042   |   V(start): 0.089
# Итерация   31   |   разность max_s|V_new(s) - V_old(s)|: 0.00030   |   V(start): 0.089
# Итерация   32   |   разность max_s|V_new(s) - V_old(s)|: 0.00021   |   V(start): 0.089
# Итерация   33   |   разность max_s|V_new(s) - V_old(s)|: 0.00014   |   V(start): 0.089
# Итерация   34   |   разность max_s|V_new(s) - V_old(s)|: 0.00009   |   V(start): 0.089
# Итерация   35   |   разность max_s|V_new(s) - V_old(s)|: 0.00006   |   V(start): 0.089
# Итерация   36   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.089
# Итерация   37   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.089
# Итерация   38   |   разность max_s|V_new(s) - V_old(s)|: 0.00002   |   V(start): 0.089
# Итерация   39   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.089
# Итерация   40   |   разность max_s|V_new(s) - V_old(s)|: 0.00001   |   V(start): 0.089
# Environment: 8x8, Slip chance: 0.3, Algorithm: value_iteration, Iterations: 18.005, Rewards: 0.577

# %% [markdown]
# | Environment | Slip Chance | Policy Iteration Iterations | Policy Iteration Rewards | Value Iteration Iterations | Value Iteration Rewards |
# |-------------|-------------|-----------------------------|--------------------------|----------------------------|-------------------------|
# | 4x4         | 0.1         | 6.297                       | 0.893                    | 6.153                      | 0.879                   |
# | 4x4         | 0.2         | 6.291                       | 0.731                    | 6.153                      | 0.702                   |
# | 4x4         | 0.3         | 6.318                       | 0.567                    | 6.291                      | 0.568                   |
# | 8x8         | 0.1         | 15.057                      | 0.885                    | 15.087                     | 0.876                   |
# | 8x8         | 0.2         | 16.434                      | 0.719                    | 16.335                     | 0.719                   |
# | 8x8         | 0.3         | 18.31                       | 0.602                    | 18.005                     | 0.577                   |

# %% [markdown]
# У Value Iterations чуть меньшее число итераций, но и средний reward тоже чуть меньше

# %% [markdown]
# # Поиск MDP, на котором Value Iteration работает достаточно долго (вплоть до 2 баллов)
#
# Когда запускали Value Iteration на небольшой задаче frozen lake, последняя итерация, на которой изменялась стратегия обучаемой политики, была под номером 6 &mdash; то есть Value Iteration находил оптимальную политику на итерации 6. Существуют ли какие-либо гарантии на то, что в общем случае поиск оптимальной политики сверху ограничен конечным числом в MDP с негораниченным горизонтом с дисконтированием? Ответ без дополнительных предположений отрицательный, более того, можно предложить пример MDP, в котором жадный алгоритм оптимизации политики будет работать произвольное наперёд заданное заданное количество итераций.
#
# Ваша задача: предъявить MDP с не более чем 3 состояниями и 2 действиями такой, что на нём алгоритм Value Iteration до останова требует, как минимум, 50 итераций. Используйте фактор дисконтирования, равный 0.95 (Однако, заметим, что величина дисконтирования тут не играет особой роли &mdash; в теории Вы можете предъявить MDP с произвольным дисконтированием, отвечающий требованиям выше.)
#
# Замечание: V-функция ценности должна измениться хотя бы один раз после 50-ой итерации (включая 50-ую итерацию), не требуется изменение V-функции на каждой итерации.

# %%
transition_probs = {
    's1': {
        'a1': {'s2': 1.0},
        'a2': {'s3': 1.0},
    },
    's2': {
        'a1': {'s3': 1.0},
        'a2': {'s1': 1.0},
    },
    's3': {
        'a1': {'s1': 1.0},
        'a2': {'s2': 1.0},
    },
}

rewards = {
    's1': {
        'a1': {'s2': 0.005},
        'a2': {'s3': 0.0},
    },
    's2': {
        'a1': {'s3': 0.005},
        'a2': {'s1': 0.0},
    },
    's3': {
        'a1': {'s1': 0.005},
        'a2': {'s2': 0.0},
    },
}

from mdp import MDP
from numpy import random
mdp = MDP(transition_probs, rewards, initial_state=random.choice(tuple(transition_probs.keys())))
# Не бойтесь изменять начальное состояние initial_state

# %%
if has_graphviz:
    display(plot_graph(mdp))

# %%
# %%time

gamma = 0.95
state_values = {s: 0 for s in mdp.get_all_states()}
policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                   for state in sorted(mdp.get_all_states())])

for i in range(100):
    print("после итерации %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1, gamma=gamma)

    new_policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                           for state in sorted(mdp.get_all_states())])

    n_changes = (policy != new_policy).sum()
    print("Количество поменявшихся действий = %i \n" % n_changes)
    policy = new_policy

# просьба игнорировать отладочный вывод "Итерация 0" на каждом шаге
# Out:
# после итерации 0
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00500   |   V(start): 0.005
# Количество поменявшихся действий = 0
#
# после итерации 1
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00475   |   V(start): 0.010
# Количество поменявшихся действий = 0
#
# после итерации 2
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00451   |   V(start): 0.014
# Количество поменявшихся действий = 0
#
# после итерации 3
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00429   |   V(start): 0.019
# Количество поменявшихся действий = 0
#
# после итерации 4
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00407   |   V(start): 0.023
# Количество поменявшихся действий = 0
#
# после итерации 5
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00387   |   V(start): 0.026
# Количество поменявшихся действий = 0
#
# после итерации 6
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00368   |   V(start): 0.030
# Количество поменявшихся действий = 0
#
# после итерации 7
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00349   |   V(start): 0.034
# Количество поменявшихся действий = 0
#
# после итерации 8
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00332   |   V(start): 0.037
# Количество поменявшихся действий = 0
#
# после итерации 9
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00315   |   V(start): 0.040
# Количество поменявшихся действий = 0
#
# после итерации 10
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00299   |   V(start): 0.043
# Количество поменявшихся действий = 0
#
# после итерации 11
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00284   |   V(start): 0.046
# Количество поменявшихся действий = 0
#
# после итерации 12
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00270   |   V(start): 0.049
# Количество поменявшихся действий = 0
#
# после итерации 13
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00257   |   V(start): 0.051
# Количество поменявшихся действий = 0
#
# после итерации 14
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00244   |   V(start): 0.054
# Количество поменявшихся действий = 0
#
# после итерации 15
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00232   |   V(start): 0.056
# Количество поменявшихся действий = 0
#
# после итерации 16
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00220   |   V(start): 0.058
# Количество поменявшихся действий = 0
#
# после итерации 17
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00209   |   V(start): 0.060
# Количество поменявшихся действий = 0
#
# после итерации 18
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00199   |   V(start): 0.062
# Количество поменявшихся действий = 0
#
# после итерации 19
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00189   |   V(start): 0.064
# Количество поменявшихся действий = 0
#
# после итерации 20
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00179   |   V(start): 0.066
# Количество поменявшихся действий = 0
#
# после итерации 21
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00170   |   V(start): 0.068
# Количество поменявшихся действий = 0
#
# после итерации 22
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00162   |   V(start): 0.069
# Количество поменявшихся действий = 0
#
# после итерации 23
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00154   |   V(start): 0.071
# Количество поменявшихся действий = 0
#
# после итерации 24
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00146   |   V(start): 0.072
# Количество поменявшихся действий = 0
#
# после итерации 25
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00139   |   V(start): 0.074
# Количество поменявшихся действий = 0
#
# после итерации 26
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00132   |   V(start): 0.075
# Количество поменявшихся действий = 0
#
# после итерации 27
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00125   |   V(start): 0.076
# Количество поменявшихся действий = 0
#
# после итерации 28
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00119   |   V(start): 0.077
# Количество поменявшихся действий = 0
#
# после итерации 29
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00113   |   V(start): 0.079
# Количество поменявшихся действий = 0
#
# после итерации 30
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00107   |   V(start): 0.080
# Количество поменявшихся действий = 0
#
# после итерации 31
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00102   |   V(start): 0.081
# Количество поменявшихся действий = 0
#
# после итерации 32
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00097   |   V(start): 0.082
# Количество поменявшихся действий = 0
#
# после итерации 33
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00092   |   V(start): 0.083
# Количество поменявшихся действий = 0
#
# после итерации 34
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00087   |   V(start): 0.083
# Количество поменявшихся действий = 0
#
# после итерации 35
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00083   |   V(start): 0.084
# Количество поменявшихся действий = 0
#
# после итерации 36
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00079   |   V(start): 0.085
# Количество поменявшихся действий = 0
#
# после итерации 37
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00075   |   V(start): 0.086
# Количество поменявшихся действий = 0
#
# после итерации 38
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00071   |   V(start): 0.086
# Количество поменявшихся действий = 0
#
# после итерации 39
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00068   |   V(start): 0.087
# Количество поменявшихся действий = 0
#
# после итерации 40
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00064   |   V(start): 0.088
# Количество поменявшихся действий = 0
#
# после итерации 41
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00061   |   V(start): 0.088
# Количество поменявшихся действий = 0
#
# после итерации 42
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00058   |   V(start): 0.089
# Количество поменявшихся действий = 0
#
# после итерации 43
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00055   |   V(start): 0.090
# Количество поменявшихся действий = 0
#
# после итерации 44
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00052   |   V(start): 0.090
# Количество поменявшихся действий = 0
#
# после итерации 45
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00050   |   V(start): 0.091
# Количество поменявшихся действий = 0
#
# после итерации 46
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00047   |   V(start): 0.091
# Количество поменявшихся действий = 0
#
# после итерации 47
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00045   |   V(start): 0.091
# Количество поменявшихся действий = 0
#
# после итерации 48
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00043   |   V(start): 0.092
# Количество поменявшихся действий = 0
#
# после итерации 49
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00040   |   V(start): 0.092
# Количество поменявшихся действий = 0
#
# после итерации 50
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00038   |   V(start): 0.093
# Количество поменявшихся действий = 0
#
# после итерации 51
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00037   |   V(start): 0.093
# Количество поменявшихся действий = 0
#
# после итерации 52
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00035   |   V(start): 0.093
# Количество поменявшихся действий = 0
#
# после итерации 53
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00033   |   V(start): 0.094
# Количество поменявшихся действий = 0
#
# после итерации 54
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00031   |   V(start): 0.094
# Количество поменявшихся действий = 0
#
# после итерации 55
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00030   |   V(start): 0.094
# Количество поменявшихся действий = 0
#
# после итерации 56
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00028   |   V(start): 0.095
# Количество поменявшихся действий = 0
#
# после итерации 57
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00027   |   V(start): 0.095
# Количество поменявшихся действий = 0
#
# после итерации 58
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00026   |   V(start): 0.095
# Количество поменявшихся действий = 0
#
# после итерации 59
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00024   |   V(start): 0.095
# Количество поменявшихся действий = 0
#
# после итерации 60
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00023   |   V(start): 0.096
# Количество поменявшихся действий = 0
#
# после итерации 61
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00022   |   V(start): 0.096
# Количество поменявшихся действий = 0
#
# после итерации 62
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00021   |   V(start): 0.096
# Количество поменявшихся действий = 0
#
# после итерации 63
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00020   |   V(start): 0.096
# Количество поменявшихся действий = 0
#
# после итерации 64
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00019   |   V(start): 0.096
# Количество поменявшихся действий = 0
#
# после итерации 65
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00018   |   V(start): 0.097
# Количество поменявшихся действий = 0
#
# после итерации 66
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00017   |   V(start): 0.097
# Количество поменявшихся действий = 0
#
# после итерации 67
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00016   |   V(start): 0.097
# Количество поменявшихся действий = 0
#
# после итерации 68
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00015   |   V(start): 0.097
# Количество поменявшихся действий = 0
#
# после итерации 69
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00015   |   V(start): 0.097
# Количество поменявшихся действий = 0
#
# после итерации 70
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00014   |   V(start): 0.097
# Количество поменявшихся действий = 0
#
# после итерации 71
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00013   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 72
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00012   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 73
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00012   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 74
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00011   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 75
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00011   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 76
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00010   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 77
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00010   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 78
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00009   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 79
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00009   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 80
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00008   |   V(start): 0.098
# Количество поменявшихся действий = 0
#
# после итерации 81
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00008   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 82
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00007   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 83
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00007   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 84
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00007   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 85
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00006   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 86
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00006   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 87
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00006   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 88
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00005   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 89
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00005   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 90
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00005   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 91
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00005   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 92
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 93
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 94
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 95
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 96
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00004   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 97
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 98
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# после итерации 99
# Итерация    0   |   разность max_s|V_new(s) - V_old(s)|: 0.00003   |   V(start): 0.099
# Количество поменявшихся действий = 0
#
# CPU times: user 19.8 ms, sys: 3.14 ms, total: 22.9 ms
# Wall time: 20.9 ms

# %% [markdown]
# Этот MDP создает ситуацию, где агент получает очень небольшое вознаграждение за выбор определенных действий.
#
# В данном примере на каждой итерации разница в оценке ценностей состояний будет очень мала, и чтобы достичь изменения в V-функции, которое удовлетворяет критерию останова, потребуется много итераций
